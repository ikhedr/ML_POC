# %%
from pymongo import MongoClient
import json
from bson import json_util
client = MongoClient('127.0.0.1',27017)
db = client['TicketTriaging']

# %%
db.TblTraining.find_one()
# Out:
# {'_id': ObjectId('5ba8e90541e12110684a18dd'),
#  'TrainingID': 1,
#  'TrainingStatus': 'InProgress',
#  'CustomerID': 1,
#  'LastTrainingBy': 'datta.ikhe',
#  'LastTrainingDate': '2018-09-24 19:09:06',
#  'PredictedFields': [{'Name': 'Resolution',
#    'VectorizationPklFile': 'def.pkl',
#    'Algorithms': [{'AlgorithmName': 'SVC',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'},
#     {'AlgorithmName': 'LogisticRegression',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'},
#     {'AlgorithmName': 'NB',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'},
#     {'AlgorithmName': 'RFClassifier',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'}]},
#   {'Name': 'App Name',
#    'VectorizationPklFile': 'def.pkl',
#    'Algorithms': [{'AlgorithmName': 'SVC',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'},
#     {'AlgorithmName': 'LogisticRegression',
#      'Accuracy': '0.8516',
# ...

# %%
db.SchemaTest.insert_one({'name':'Datta', 'mob': 9665747808})

# %%
cursor = db.SchemaTest.find({},{'_id':0})

# %%
lst_cursor_out = list(cursor)

# %%
lst_cursor_out
# Out:
# [{'add': 'Kaij', 'mob': 9665747808, 'name': 'Datta'},
#  {'add': 'Kaij', 'mob': 9665747808, 'name': 'Datta'}]

# %%
json_util.dumps(lst_cursor_out)
# Out:
# '[{"_id": {"$oid": "5ba76424bcb3a73190b1b12d"}, "name": "Datta", "mob": 9665747808}, {"_id": {"$oid": "5ba76430bcb3a73190b1b12e"}, "name": "Datta", "mob": 9665747808}]'

# %%
json.dumps(lst_cursor_out)
# Out:
# '[{"name": "Datta", "mob": 9665747808}, {"name": "Datta", "mob": 9665747808}]'

# %%
json_util_out = json_util.dumps(cursor)

# %%
json_util_out
# Out:
# '[{"_id": {"$oid": "5ba76424bcb3a73190b1b12d"}, "name": "Datta", "mob": 9665747808}, {"_id": {"$oid": "5ba76430bcb3a73190b1b12e"}, "name": "Datta", "mob": 9665747808}]'

# %% [markdown]
# # Unique & Required

# %% [markdown]
# ## Preparing to work with TblTraining

# %% [raw]
# #MongoDBStyle: Execute in mongoDB... Dont execute in Python
# db.createCollection( "TblTraining", {
#    validator: { $jsonSchema: {
#       bsonType: "object",
#       required: [ "TrainingID","CustomerID","TrainingStatus" ],
#       properties: {
#          TrainingID: {
#             bsonType: "int",
#             description: "must be a int and is required"
#          },
#           CustomerID: {
#             bsonType : "int",
#             description: "must be a int and is required"
#          },
#           Accuracy: {
#                bsonType: ["double"],
#                minimum: 0,
#                description: "must be a double and is required"
#           },
#           TrainingStatus: {
#             enum: ["InProgress","Accepted","Archived"],
#             description: "can only be one of the enum values"
#          }
#       }
#    } }
# } )

# %%
#import pymongo

# %% [markdown]
# ### Getting LastTrainingBy & LastTrainingDate

# %%
from datetime import datetime
import os

#LastTrainingBy
LastTrainingBy = os.getlogin()

#LastTrainingDate
today1 = str(datetime.now())
LastTrainingDate = today1[:19]

# %%
LastTrainingBy
# Out:
# 'datta'

# %%
LastTrainingDate
# Out:
# '2018-09-24 22:03:09'

# %% [markdown]
# ### Generating TrainingID

# %%
mongo = MongoClient("mongodb://127.0.0.1:27017")

# %%
db  = mongo.TicketTriaging

# %%
db.TblTraining.find_one({})
# Out:
# {'_id': ObjectId('5ba8e90541e12110684a18dd'),
#  'TrainingID': 1,
#  'TrainingStatus': 'InProgress',
#  'CustomerID': 1,
#  'LastTrainingBy': 'datta.ikhe',
#  'LastTrainingDate': '2018-09-24 19:09:06',
#  'PredictedFields': [{'Name': 'Resolution',
#    'VectorizationPklFile': 'def.pkl',
#    'Algorithms': [{'AlgorithmName': 'SVC',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'},
#     {'AlgorithmName': 'LogisticRegression',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'},
#     {'AlgorithmName': 'NB',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'},
#     {'AlgorithmName': 'RFClassifier',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'}]},
#   {'Name': 'App Name',
#    'VectorizationPklFile': 'def.pkl',
#    'Algorithms': [{'AlgorithmName': 'SVC',
#      'Accuracy': '0.8516',
#      'PredictionPklFile': 'abc.pkl'},
#     {'AlgorithmName': 'LogisticRegression',
#      'Accuracy': '0.8516',
# ...

# %%
try:
    conn = MongoClient("mongodb://10.10.12.23:27017")
except:
    print("Could not connect to server: %s")

# %%
cust_info_dict =  db.TblCustomer.find_one({'CustomerID':1},{'CustomerName':1,'PredictedFields':1, '_id':0})

# %%
cust_info_dict['CustomerName']
# Out:
# 'AMD'

# %%
if(algo_listOfDicts):
    print('We are good')
else:
    print('Algorithms not found.. Please add any of ')
# Out:
# Algorithms not found.. Please add any of

# %%
if(last_training_dict):
    last_training_id = last_training_dict['TrainingID']
else:
    print("Please register us before using the our TRAIN functionality")
# Out:
# Please register us before using the TRAIN functionality

# %%
#db.TblTraining.find({"CustomerID" : 1},{'_id':0,'TrainingID': 1}).sort({'TrainingID':-1}).limit(1)
last_training_dict = db.TblTraining.find_one({"CustomerID" : 4, "TrainingID": {"$exists": True}},{'_id':0,"TrainingID":1}, sort=[("TrainingID", -1)])

# %%
#TrainingID is customer specific... It tracks different versions of training for the customer
#So TrainigID can be duplicate between different customer
last_training_id

#Primary key: TrainingID & CustomerID
# Out:
# 5

# %%
cust_id = 1
#list(db.TblCustomer.find({'CustomerID':cust_id},{'CustomerName':1,'_id':0}))[0]['CustomerName']
db.TblCustomer.find_one({'CustomerID':cust_id},{'CustomerName':1,'_id':0})['CustomerName']
# Out:
# 'AMD'

# %%
db.TblTraining.count_documents({"CustomerID" : 1})
# Out:
# 2

# %% [markdown]
# ### Getting PredictedFields :
#     list of dictionaries
#     where each dictionary is prediction Field
#     in each prediction field has attributes

# %%
Algorithms = []

# %%
a1 = {}

# %%
a1["Accuracy" ] = 0.90

# %%
a1
# Out:
# {'Accuracy': 0.9}

# %%
Algorithms.append(a1)

# %%
Algorithms
# Out:
# [{'Accuracy': 0.9}]

# %%
pred_field_dict = {}
pred_field_dict["Name"] = 'Assignment group'
pred_field_dict["VectorizationPklFile"] = 'abc.pkl'
pred_field_dict["Algorithms"] = Algorithms

# %%
pred_field_dict
# Out:
# {'Algorithms': [],
#  'Name': 'Assignment group',
#  'VectorizationPklFile': 'abc.pkl'}

# %%
#predicted_fields_data = []
predicted_fields_data.append(pred_field_dict)

# %%
predicted_fields_data
# Out:
# [{'Algorithms': [{'Accuracy': '0.8516',
#     'AlgorithmName': 'SVC',
#     'PredictionPklFile': 'abc.pkl'},
#    {'Accuracy': '0.8516',
#     'AlgorithmName': 'LogisticRegression',
#     'PredictionPklFile': 'abc.pkl'}],
#   'Name': 'Assignment group',
#   'VectorizationPklFile': 'abc.pkl'},
#  {'Algorithms': [{'Accuracy': '0.8516',
#     'AlgorithmName': 'SVC',
#     'PredictionPklFile': 'abc.pkl'},
#    {'Accuracy': '0.8516',
#     'AlgorithmName': 'LogisticRegression',
#     'PredictionPklFile': 'abc.pkl'}],
#   'Name': 'Assignment group',
#   'VectorizationPklFile': 'abc.pkl'}]

# %%
try:
    db.TblTraining.insert_one({
    "TrainingID" : 3,
    "TrainingStatus" : "InProgress",
    "CustomerID" : 2,
    "LastTrainingBy" : LastTrainingBy,
    "LastTrainingDate" : LastTrainingDate,
    "PredictedFields" : [ 
            
        {
            "Name" : "AssignmentGroup",
            "VectorizationPklFile" : "def.pkl",
            "Algorithms" : [ 
                {
                    "AlgorithmName" : "SVC",
                    "Accuracy" : "0.8516",
                    "PredictionPklFile" : "abc.pkl"
                }, 
                {
                    "AlgorithmName" : "LogisticRegression",
                    "Accuracy" : "0.8516",
                    "PredictionPklFile" : "abc.pkl"
                }, 
                {
                    "AlgorithmName" : "NB",
                    "Accuracy" : "0.8516",
                    "PredictionPklFile" : "abc.pkl"
                }, 
                {
                    "AlgorithmName" : "RFClassifier",
                    "Accuracy" : "0.8516",
                    "PredictionPklFile" : "abc.pkl"
                }
            ]
        }
    ]
})
except Exception as e:
    print(e)

# %%
list(db.TblTraining.find({},{'_id':0}))
# Out:
# [{'Accuracy': 90.0,
#   'AlgorithmID': 1,
#   'CustomerID': 1,
#   'LastTrainingBy': 'datta',
#   'LastTrainingDate': '2018-09-23 16:32:14',
#   'TrainingID': 1,
#   'TrainingStatus': 'InProgress'}]

# %% [markdown]
# ## Preparing to work with TblCustomer

# %% [raw]
# #MongoDBStyle: Execute in mongoDB... Dont execute in Python
# db.createCollection( "TblCustomer", {
#    validator: { $jsonSchema: {
#       bsonType: "object",
#       required: ["CustomerID","CustomerName" ],
#       properties: {
#          CustomerID: {
#             bsonType: "int",
#             description: "must be a int and is required"
#          },
#           CustomerName: {
#             bsonType : "string",
#             description: "must be a string and is required"
#          }
#       }
#    } }
# } )

# %%
if(db.TblCustomer.count_documents({})==0):
    print('No records')
else:
    print('There are records')
# Out:
# No records

# %%
try:
    db.TblCustomer.insert_one({
    "CustomerID" : 1,
    "CustomerName" : "AMD",
    "DataSetName": "TicketDataset",
    "RecordCreatedBy" : "Datta",
    "RecordCreatedDate" : LastTrainingDate,
    "FieldsStatus" : "InProgress",
    "PredictedFields" : [ 
        {
            "PredictedFieldName" : "Assignment_group",
            "InputFields" : [ 
                "Description", 
                "Priority"
            ],
            "AlgorithmName" : "SVC"
        }, 
        {
            "PredictedFieldName" : "App Name",
            "InputFields" : [ 
                "Description"
            ],
            "AlgorithmName" : "RFClassifier"
        }, 
        {
            "PredictedFieldName" : "Resolution",
            "InputFields" : [ 
                "Description", 
                "Priority"
            ],
            "AlgorithmName" : "NaiveBayes"
        }
    ]
})
except Exception as e:
    print(e)

# %%
pred_list = db.TblCustomer.find_one({'CustomerID': 1})['PredictedFields']

# %%
#seperate out predicted fields
pred_field_list = []
for pre_field in pred_list:
    pred_field_list.append(pre_field['PredictedFieldName'])

# %%
pred_field_list
# Out:
# ['Assignment_group', 'Task_type', 'Subcategory']

# %%
pred_field = "Task_type"
input_list = db.TblCustomer.find_one({'CustomerID': 1})['PredictedFields']
input_field_list =  []
for in_field in input_list:
    if(in_field['PredictedFieldName'] == pred_field):
        input_field_list = in_field['InputFields']

# %%
input_field_list
# Out:
# ['Description']

# %% [markdown]
# ### Creating TblIncidentTraining & TblAlgorithm

# %% [raw]
# #MongoDBStyle: Execute in mongoDB... Dont execute in Python
# db.createCollection( "TblIncidentRT", {
#    validator: { $jsonSchema: {
#       bsonType: "object",
#       required: ["IncidentNumber","CustomerID"],
#       properties: {
#          CustomerID: {
#             bsonType: "int",
#             description: "must be a int and is required"
#          },
#           IncidentNumber: {
#             bsonType : "string",
#             description: "must be a string and is required"
#          }
#       }
#    } }
# } )

# %% [raw]
# #MongoDBStyle: Execute in mongoDB... Dont execute in Python
# db.createCollection( "TblIncidentData", {
#    validator: { $jsonSchema: {
#       bsonType: "object",
#       required: ["IncidentNumber","CustomerID","TrainingFlag"],
#       properties: {
#          CustomerID: {
#             bsonType: "int",
#             description: "must be a int and is required"
#          },
#           IncidentNumber: {
#             bsonType : "string",
#             description: "must be a string and is required"
#          },
#           TrainingFlag: {
#             bsonType : "int",
#             description: "must be a string and is required"
#          }
#       }
#    } }
# } )

# %% [raw]
# #MongoDBStyle: Execute in mongoDB... Dont execute in Python
# db.createCollection( "TblAlgorithm", {
#    validator: { $jsonSchema: {
#       bsonType: "object",
#       required: ["AlgorithmID","AlgorithmName" ],
#       properties: {
#          AlgorithmID
# : {
#             bsonType: "int",
#             description: "must be a int and is required"
#          },
#           AlgorithmName: {
#             bsonType : "string",
#             description: "must be a string and is required"
#          }
#       }
#    } }
# } )

# %%
#Insert into TblAlgorithm

# %%
try:
    db.TblAlgorithm.insert_many([
{
    "AlgorithmID" : 1,
    "AlgorithmName" : "LogisticRegression",
    "RecordCreatedBy":LastTrainingBy,
    "RecordCreatedDate":LastTrainingDate

},
{
    "AlgorithmID" : 2,
    "AlgorithmName" : "RFClassifier",
    "RecordCreatedBy":LastTrainingBy,
    "RecordCreatedDate":LastTrainingDate
},
{
    "AlgorithmID" : 3,
    "AlgorithmName" : "SVC",
    "RecordCreatedBy":LastTrainingBy,
    "RecordCreatedDate":LastTrainingDate
},
{
    "AlgorithmID" : 4,
    "AlgorithmName" : "MultinomialNB",
    "RecordCreatedBy":LastTrainingBy,
    "RecordCreatedDate":LastTrainingDate
}])
except Exception as e:
    return (e)

# %%
pred_field = "Task_type"
import pandas as pd
training_tkt_df =  pd.DataFrame(list(db.TblIncidentData.find({'CustomerID':1},{'_id':0,pred_field:1})))

if(training_tkt_df.empty):
    print('hey')

# %%
training_tkt_df.head()
# Out:
#   Task_type
# 0  Incident
# 1  Incident
# 2  Incident
# 3  Incident
# 4  Incident

# %%
training_tkt_df['in_field'] = input_df1

# %%
training_tkt_df['category_id'] = training_tkt_df[pred_field].factorize()[0]

# %%
training_tkt_df = training_tkt_df[pd.notnull(training_tkt_df['in_field'])]

# %%
training_tkt_df
# Out:
#    Task_type                                           in_field  category_id
# 0   Incident      nan4 - Low (Resolution SLA ? 5 Business days)            0
# 1   Incident  (CI=SAP HCM (Human Capital Management))Job "ZH...            0
# 2   Incident  (CI=SAP BPC NW EPM (Product & Cust Eng - PCE))...            0
# 3   Incident  (CI=SAP BPC NW EPM (Project Base Accounting - ...            0
# 4   Incident  (CI=SAP ERP FI (Finance))JC_ZFICO_B_AR_DLY_ATL...            0
# 5   Incident  (CI=SAP ERP FI (Finance))ZFICO_B1_AR_DLY_PRars...            0
# 6   Incident  (CI=SAP HCM (Human Capital Management))ZHCM_OM...            0
# 7   Incident  (CI=SAP HCM (Human Capital Management))JC_ZHCM...            0
# 8   Incident  (CI=SAP HCM (Human Capital Management))JC_ZHCM...            0
# 9   Incident  (CI=SAP HCM (Human Capital Management))ZHCM_BN...            0
# 10  Incident  (CI=SAP BW(Business Warehouse))Redwood PRD: Jo...            0
# ...

# %%
import pandas as pd
input_field_list = ['Description','Priority']

# %%
input_df1 = pd.DataFrame()

# %%
input_df = pd.DataFrame(list(db.TblIncidentTraining.find({'CustomerID':1},{'_id':0,'Description':1})))

# %%
input_df1['Description'] = input_df

# %%
input_df1
# Out:
#                                       Priority  \
# 0   4 - Low (Resolution SLA ? 5 Business days)
# 1   4 - Low (Resolution SLA ? 5 Business days)
# 2   4 - Low (Resolution SLA ? 5 Business days)
# 3   4 - Low (Resolution SLA ? 5 Business days)
# 4   4 - Low (Resolution SLA ? 5 Business days)
# 5   4 - Low (Resolution SLA ? 5 Business days)
# 6   4 - Low (Resolution SLA ? 5 Business days)
# 7   4 - Low (Resolution SLA ? 5 Business days)
# 8   4 - Low (Resolution SLA ? 5 Business days)
# 9   4 - Low (Resolution SLA ? 5 Business days)
# 10  4 - Low (Resolution SLA ? 5 Business days)
# 11  4 - Low (Resolution SLA ? 5 Business days)
# 12  4 - Low (Resolution SLA ? 5 Business days)
# 13  4 - Low (Resolution SLA ? 5 Business days)
# 14  4 - Low (Resolution SLA ? 5 Business days)
# 15  4 - Low (Resolution SLA ? 5 Business days)
# 16  4 - Low (Resolution SLA ? 5 Business days)
# 17  4 - Low (Resolution SLA ? 5 Business days)
# 18  4 - Low (Resolution SLA ? 5 Business days)
# ...

# %%
input_df = pd.DataFrame()
for input_field_ in input_field_list:
    input_df[input_field_] = pd.DataFrame(list(db.TblIncidentTraining.find({'CustomerID':1},{'_id':0,input_field_:1})))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\frame.py in _ensure_valid_index(self, value)
#    3169             try:
# -> 3170                 value = Series(value)
#    3171             except:
#
# D:\anaconda\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     275
# --> 276                 data = SingleBlockManager(data, index, fastpath=True)
#     277
#
# D:\anaconda\lib\site-packages\pandas\core\internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    4676         if not isinstance(block, Block):
# -> 4677             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    4678
#
# D:\anaconda\lib\site-packages\pandas\core\internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3204
# ...

# %%
input_df
# Out:
#                                       Priority
# 0   4 - Low (Resolution SLA ? 5 Business days)
# 1   4 - Low (Resolution SLA ? 5 Business days)
# 2   4 - Low (Resolution SLA ? 5 Business days)
# 3   4 - Low (Resolution SLA ? 5 Business days)
# 4   4 - Low (Resolution SLA ? 5 Business days)
# 5   4 - Low (Resolution SLA ? 5 Business days)
# 6   4 - Low (Resolution SLA ? 5 Business days)
# 7   4 - Low (Resolution SLA ? 5 Business days)
# 8   4 - Low (Resolution SLA ? 5 Business days)
# 9   4 - Low (Resolution SLA ? 5 Business days)
# 10  4 - Low (Resolution SLA ? 5 Business days)
# 11  4 - Low (Resolution SLA ? 5 Business days)
# 12  4 - Low (Resolution SLA ? 5 Business days)
# 13  4 - Low (Resolution SLA ? 5 Business days)
# 14  4 - Low (Resolution SLA ? 5 Business days)
# 15  4 - Low (Resolution SLA ? 5 Business days)
# 16  4 - Low (Resolution SLA ? 5 Business days)
# 17  4 - Low (Resolution SLA ? 5 Business days)
# 18  4 - Low (Resolution SLA ? 5 Business days)
# ...

# %%
input_df = input_df[pd.notnull(input_df['Description'])]

# %%
input_df.count()
# Out:
# Description    49
# Priority       49
# dtype: int64

# %%
input_df['in_field'] = input_df[input_field_list].astype(str).sum(axis=1)

# %%
input_df['in_field'] = input_df.loc[:,input_field_list].astype(str).sum(axis=1)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
input_df1['in_field'] = input_df['in_field']

# %%
input_df['in_field'] = input_df

# %%
input_df1['in_field'][0]
# Out:
# 'nan4 - Low (Resolution SLA ? 5 Business days)'

# %%
input_df = input_df[pd.notnull(input_df['Description'])]

# %%
def remove_html_tags(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)
def remove_special_char(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<')
    return re.sub(clean, '', text)
for index,row in input_df1.iterrows():
    row['in_field'] = remove_html_tags(row['in_field'])

# %%
esult = pd.concat(input_df_list)

# %%
esult
# Out:
#                                           Description  \
# 0                                                 NaN
# 1   (CI=SAP HCM (Human Capital Management))Job "ZH...
# 2   (CI=SAP BPC NW EPM (Product & Cust Eng - PCE))...
# 3   (CI=SAP BPC NW EPM (Project Base Accounting - ...
# 4   (CI=SAP ERP FI (Finance))JC_ZFICO_B_AR_DLY_ATL...
# 5   (CI=SAP ERP FI (Finance))ZFICO_B1_AR_DLY_PRars...
# 6   (CI=SAP HCM (Human Capital Management))ZHCM_OM...
# 7   (CI=SAP HCM (Human Capital Management))JC_ZHCM...
# 8   (CI=SAP HCM (Human Capital Management))JC_ZHCM...
# 9   (CI=SAP HCM (Human Capital Management))ZHCM_BN...
# 10  (CI=SAP BW(Business Warehouse))Redwood PRD: Jo...
# 11  (CI=SAP BPC NW EPM (Product & Cust Eng - PCE))...
# 12  (CI=SAP BPC NW EPM (Project Base Accounting - ...
# 13  (CI=SAP ERP SD (Sales and Distribution))  PRD:...
# 14  (CI=SAP ERP FI (Finance))ZFICO_B1_AR_DLY_PRars...
# 15  (CI=SAP ERP SD (Sales and Distribution))  PRD:...
# ...

# %%
input_df_list
# Out:
# [                                          Description
#  0                                                 NaN
#  1   (CI=SAP HCM (Human Capital Management))Job "ZH...
#  2   (CI=SAP BPC NW EPM (Product & Cust Eng - PCE))...
#  3   (CI=SAP BPC NW EPM (Project Base Accounting - ...
#  4   (CI=SAP ERP FI (Finance))JC_ZFICO_B_AR_DLY_ATL...
#  5   (CI=SAP ERP FI (Finance))ZFICO_B1_AR_DLY_PRars...
#  6   (CI=SAP HCM (Human Capital Management))ZHCM_OM...
#  7   (CI=SAP HCM (Human Capital Management))JC_ZHCM...
#  8   (CI=SAP HCM (Human Capital Management))JC_ZHCM...
#  9   (CI=SAP HCM (Human Capital Management))ZHCM_BN...
#  10  (CI=SAP BW(Business Warehouse))Redwood PRD: Jo...
#  11  (CI=SAP BPC NW EPM (Product & Cust Eng - PCE))...
#  12  (CI=SAP BPC NW EPM (Project Base Accounting - ...
#  13  (CI=SAP ERP SD (Sales and Distribution))  PRD:...
#  14  (CI=SAP ERP FI (Finance))ZFICO_B1_AR_DLY_PRars...
#  15  (CI=SAP ERP SD (Sales and Distribution))  PRD:...
# ...

# %%
try:
    db.TblIncidentRT.insert_many([{
    "IncidentNumber" : "INC0787763",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP Data Archiving) Redwood PRD: Job ended with an error.",
    "Assignment_group" : "SAP Basis Support",
    "Assigned_to" : "santhosh kumar Siddamsetty (siddams)",
    "State" : "Closed",
    "Created" : "30-07-2018 05:33",
    "Closed" : "08-08-2018 08:19",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Application Issue",
    "Closed_by" : "santhosh kumar Siddamsetty (siddams)",
    "Close_notes" : "House keeping job failed with variant does not exist issue.We have created it",
    "Type" : "2",
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0787773",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))ZHCM_PY_WKS_CA_IDOC_Master_Data_Ca_2_NUS (59176901) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Hare Dora (hdora)",
    "State" : "Closed",
    "Created" : "30-07-2018 06:52",
    "Closed" : "31-07-2018 11:25",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Definition",
    "Closed_by" : "Hare Dora (hdora)",
    "Close_notes" : "Issue:Job ended with status ErrorRCA:Script errorSummary:SG&A team is working on the script changes.Hence closing the ticket. ",
    "Type" : "2",
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0787774",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_PY_ADP_NUS (59176893) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Hare Dora (hdora)",
    "State" : "Closed",
    "Created" : "30-07-2018 06:52",
    "Closed" : "31-07-2018 11:26",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Definition",
    "Closed_by" : "Hare Dora (hdora)",
    "Close_notes" : "Issue:Job ended with status ErrorRCA:Script errorSummary:SG&A team is working on the script changes.Hence closing the ticket. ",
    "Type" : "2",
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0787937",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BPC NW EPM (Cost Centre Reporting)ATL Redwood PRD: BPC Redwood Job ZPC_CCR_PERF Ended Not Ok.",
    "Assignment_group" : "SAP BPC Support",
    "Assigned_to" : "Suvarna Vandana (suvarna)",
    "State" : "Closed",
    "Created" : "30-07-2018 19:57",
    "Closed" : "31-07-2018 07:02",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BPC NW EPM (Cost Centre Reporting)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Hung",
    "Closed_by" : "Ramakrishna reddy Kothakapu (rkothaka)",
    "Close_notes" : "Job is completed",
    "Type" : "2",
    "CustomerID" : 1
}]
)
except Exception as e:
    print(e.details)

# %%
try:
    db.TblIncidentData.insert_many([
{
    "IncidentNumber" : "INC0697190",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Assignment_group" : "SAP BW Support",
    "Assigned_to" : "Suganya Balasubramani (sbalasu)",
    "State" : "Closed",
    "Created" : "8/1/2017 15:04",
    "Closed" : "8/1/2017 18:47",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BW(Business Warehouse)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Failure alert delay",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "ISSUE:ZRET_SNAP_T_D_F is failed.RCA:Due to background job cancellation from BWP systemResolution Summary:Deleted the red request and repeated the step.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697200",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))Job \"ZHCM_WW_CYC_Load_WWHRDB_Hourly_Data_To_HRETL_Database_NUS\"  (47120848) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/1/2017 15:39",
    "Closed" : "8/3/2017 15:11",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Definition",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "issue:(CI=SAP HCM (Human Capital Management))Job \"ZHCM_WW_CYC_Load_WWHRDB_Hourly_Data_To_HRETL_Database_NUS\"  (47120848) ended with status ErrorRCA:N/ASolution:After monitoring few runs  job has ended successfully.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697212",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BPC NW EPM (Product & Cust Eng - PCE))ATL Redwood PRD: BPC Redwood Job ZPC_CCR_INT Ended Not Ok.",
    "Assignment_group" : "SAP BPC Support",
    "Assigned_to" : "Firoze Shaik (fishaik)",
    "State" : "Closed",
    "Created" : "8/1/2017 17:02",
    "Closed" : "8/3/2017 16:23",
    "Task_type" : "Incident",
    "Subcategory" : "Planning, Budgeting, Forecasting",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BPC NW (Business Planning and Consolidation)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Connection Issue",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "ISsue:(CI=SAP BPC NW EPM (Product & Cust Eng - PCE))ATL Redwood PRD: BPC Redwood Job ZPC_CCR_INT Ended Not Ok.RCA:Due to some duplicate nodes from SAP Master Data hierarchy in BPC getting failed.Resolution summary:CBG Team resolved the issue.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697213",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BPC NW EPM (Project Base Accounting - PBA))ATL Redwood PRD: BPC Redwood Job ZPC_PBA_MD Ended Not Ok.",
    "Assignment_group" : "SAP BPC Support",
    "Assigned_to" : "Firoze Shaik (fishaik)",
    "State" : "Closed",
    "Created" : "8/1/2017 17:02",
    "Closed" : "8/3/2017 16:11",
    "Task_type" : "Incident",
    "Subcategory" : "Planning, Budgeting, Forecasting",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BPC NW (Business Planning and Consolidation)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Incorrect/Missing Data",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "ISsue:(CI=SAP BPC NW EPM (Project Base Accounting - PBA))ATL Redwood PRD: BPC Redwood Job ZPC_PBA_MD Ended Not Ok.RCA:Due to some duplicate nodes from SAP Master Data hierarchy in BPC getting failed.Resolution Summary:Resolved by cBG team",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697369",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP FI (Finance))JC_ZFICO_B_AR_DLY_ATLUT (47110773) ended with status Error",
    "Assignment_group" : "SAP SD Support",
    "Assigned_to" : "Rajender reddy Baradi (rbaradi)",
    "State" : "Closed",
    "Created" : "8/2/2017 7:36",
    "Closed" : "8/3/2017 10:38",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Duplicate",
    "Closure_CI" : "SAP ERP SD (Sales and Distribution)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job Stuck/Error",
    "Closed_by" : "Rajender reddy Baradi (rbaradi)",
    "Close_notes" : "issue:(CI=SAP ERP FI (Finance))JC_ZFICO_B_AR_DLY_ATLUT (47110773) ended with status ErrorRCA:tracked under INC0696750.Hence closing the incident.Resolution:tracked under INC0696750.Hence closing the incident.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0697370",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP FI (Finance))ZFICO_B1_AR_DLY_PRars118D_SAP (47110775) ended with status Killed",
    "Assignment_group" : "SAP SD Support",
    "Assigned_to" : "Harish Munigela (hmunigel)",
    "State" : "Closed",
    "Created" : "8/2/2017 7:36",
    "Closed" : "8/3/2017 17:26",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP SD (Sales and Distribution)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Data Error",
    "Closed_by" : "Harish Munigela (hmunigel)",
    "Close_notes" : "Issue: (CI=SAP ERP FI (Finance))ZFICO_B1_AR_DLY_PRars118D_SAP (47110775) ended with status KilledRoot cause: Due to bug in the program, interpretation of number is causing the issue.Solution: Working on the resolution with incident #INC0697061 ",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0697423",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))ZHCM_OM_DLY_Remove_Roles_From_Chiefs_Automating_Chief_Roles_NUS (47118572) ended with status Killed",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Pavitra Kanneganti (pkannega)",
    "State" : "Closed",
    "Created" : "8/2/2017 12:47",
    "Closed" : "8/2/2017 13:58",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Duplicate",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "The redwood  job is working fine,  there is no issue.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0697424",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Roles_NUS (47118568) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/2/2017 12:47",
    "Closed" : "8/2/2017 14:03",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Duplicate",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "issue:(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Chief_Roles_NUS (47118561) ended with status ErrorRCA:N/Asolution:closing this as a duplicate.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0697425",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Chief_Roles_NUS (47118561) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/2/2017 12:47",
    "Closed" : "8/2/2017 14:00",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Duplicate",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "issue:(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Chief_Roles_NUS (47118561) ended with status ErrorRCA:N/Asolution:closing this as a duplicate.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0697459",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))ZHCM_BN_DLY_Extract_Employee_Master_Data_For_ASIA_NUS (47133129) ended with status Killed",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/2/2017 15:20",
    "Closed" : "8/7/2017 18:20",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Definition",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "issue:(CI=SAP HCM (Human Capital Management))ZHCM_BN_DLY_Extract_Employee_Master_Data_For_ASIA_NUS (47133129) ended with status KilledRCA:N/Asolution:closing this incident as job has completed successfully.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0697473",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BW(Business Warehouse))Redwood PRD: Job Ended Not OK.",
    "Assignment_group" : "SAP BW Support",
    "Assigned_to" : "Suganya Balasubramani (sbalasu)",
    "State" : "Closed",
    "Created" : "8/2/2017 16:03",
    "Closed" : "8/3/2017 10:23",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BW(Business Warehouse)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Failure alert delay",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "ISSUE:ZBILLING job is failed.RCA:Due to concellation of background jobRESOLUTION SUMMARY:manually ran the job.job is completed.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697485",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BPC NW EPM (Product & Cust Eng - PCE))ATL Redwood PRD: BPC Redwood Job ZPC_CCR_INT Ended Not Ok.",
    "Assignment_group" : "SAP BPC Support",
    "Assigned_to" : "Suvarna Vandana (suvarna)",
    "State" : "Closed",
    "Created" : "8/2/2017 17:02",
    "Closed" : "8/3/2017 16:05",
    "Task_type" : "Incident",
    "Subcategory" : "Planning, Budgeting, Forecasting",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BPC NW (Business Planning and Consolidation)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Data Error",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "Issue:(CI=SAP BPC NW EPM (Product & Cust Eng - PCE))ATL Redwood PRD: BPC Redwood Job ZPC_CCR_INT Ended Not Ok.RCA:Due to some error charactersResolution Summary:CBG team resolved the issue.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697486",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BPC NW EPM (Project Base Accounting - PBA))ATL Redwood PRD: BPC Redwood Job ZPC_PBA_MD Ended Not Ok.",
    "Assignment_group" : "SAP BPC Support",
    "Assigned_to" : "Firoze Shaik (fishaik)",
    "State" : "Closed",
    "Created" : "8/2/2017 17:02",
    "Closed" : "8/3/2017 15:33",
    "Task_type" : "Incident",
    "Subcategory" : "Planning, Budgeting, Forecasting",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BPC NW (Business Planning and Consolidation)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Incorrect/Missing Data",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "ISsue:(CI=SAP BPC NW EPM (Project Base Accounting - PBA))ATL Redwood PRD: BPC Redwood Job ZPC_PBA_MD Ended Not Ok.RCA:Due to some duplicate nodes from SAP Master Data hierarchy in BPC getting failed.resolution Summary:CBG team Resolved the issue.PC ran to success",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697638",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP SD (Sales and Distribution))  PRD: (Job \"ZSDLE_CYC_REC_ShipInfoDHL1\"- Receive Ship Info From DHL1) being set to status Error.",
    "Assignment_group" : "SAP SD Support",
    "Assigned_to" : "Rajender reddy Baradi (rbaradi)",
    "State" : "Closed",
    "Created" : "8/3/2017 5:03",
    "Closed" : "8/4/2017 11:57",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP SD (Sales and Distribution)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job Stuck/Error",
    "Closed_by" : "Rajender reddy Baradi (rbaradi)",
    "Close_notes" : "Issue:(CI=SAP ERP SD (Sales and Distribution))  PRD: (Job \"ZSDLE_CYC_REC_ShipInfoDHL1\"- Receive Ship Info From DHL1) being set to status Error.RCA: its an intermittent issueResolution: its an intermittent issue,Hence closing the incident.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697657",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP FI (Finance))ZFICO_B1_AR_DLY_PRars118D_SAP (47143860) ended with status Killed",
    "Assignment_group" : "Redwood Support",
    "Assigned_to" : "Vinay kumar Balivada (vbalivad)",
    "State" : "Closed",
    "Created" : "8/3/2017 7:33",
    "Closed" : "8/7/2017 22:51",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job Stuck/Error",
    "Closed_by" : "Vinay kumar Balivada (vbalivad)",
    "Close_notes" : "Issue:(CI=SAP ERP FI (Finance))ZFICO_B1_AR_DLY_PRars118D_SAP (47143860) ended with status Killed.RCA:One of the steps in the given job chain has failed because the job in the step has ABAP code \"ZCREDITGET\" that had to be terminated because it had come across a statement that unfortunately cannot be executed. It was unable to interpret \" 1,250.00\" as a number. Resolution:The ABAP code was later changed so that the statement can be executed. Susequent runs were completed and the job is running fine now.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697707",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP SD (Sales and Distribution))  PRD: (Job \"ZSDLE_CYC_MOV_ShipInfoErrModus\"- FTP Ship Info Error to ModusLink) being set to status Error.",
    "Assignment_group" : "SAP SD Support",
    "Assigned_to" : "Rajender reddy Baradi (rbaradi)",
    "State" : "Closed",
    "Created" : "8/3/2017 12:15",
    "Closed" : "8/4/2017 12:00",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP SD (Sales and Distribution)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job Stuck/Error",
    "Closed_by" : "Rajender reddy Baradi (rbaradi)",
    "Close_notes" : "Issue:(CI=SAP ERP SD (Sales and Distribution))  PRD: (Job \"ZSDLE_CYC_REC_ShipInfoDHL1\"- Receive Ship Info From DHL1) being set to status Error.RCA: its an intermittent issueResolution: its an intermittent issue,Hence closing the incident.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697719",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))ZHCM_OM_DLY_Update_PD_Profile_In_PRD_Automating_Chief_Roles_NUS (47151320) ended with status Killed",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/3/2017 12:47",
    "Closed" : "8/3/2017 15:07",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Duplicate",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "issue:(CI=SAP HCM (Human Capital Management))ZHCM_OM_DLY_Update_PD_Profile_In_PRD_Automating_Chief_Roles_NUS (47151320) ended with status KilledRCA:N/Asolution:Closing this as a duplicate.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0697720",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Roles_NUS (47151306) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/3/2017 12:47",
    "Closed" : "8/3/2017 15:05",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Duplicate",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "issue:(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Roles_NUS (47151306) ended with status ErrorRCA:N/Asolution:closing this as a duplicate.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697721",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Chief_Roles_NUS (47151299) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/3/2017 12:47",
    "Closed" : "8/3/2017 15:00",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Definition",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "issue:(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Chief_Roles_NUS (47151299) ended with status ErrorRCA:N/Asolution: closing this as a duplicate as we are working on the same.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697735",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP SD (Sales and Distribution))  PRD: (Job \"ZSDLE_CYC_REC_ShipInfoModus\"- Receive Ship Info From ModusLink) being set to status Error.",
    "Assignment_group" : "SAP SD Support",
    "Assigned_to" : "Rajender reddy Baradi (rbaradi)",
    "State" : "Closed",
    "Created" : "8/3/2017 14:01",
    "Closed" : "8/4/2017 12:06",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP SD (Sales and Distribution)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job Stuck/Error",
    "Closed_by" : "Rajender reddy Baradi (rbaradi)",
    "Close_notes" : "issue:((CI=SAP ERP SD (Sales and Distribution))  PRD: (Job \"ZSDLE_CYC_REC_ShipInfoModus\"- Receive Ship Info From ModusLink) being set to status Error.RCA: its an intermittent issueResolution: its an intermittent issue,Hence closing the incident.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0697971",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BW(Business Warehouse))Redwood PRD: Job Ended Not OK.",
    "Assignment_group" : "SAP BW Support",
    "Assigned_to" : "Suganya Balasubramani (sbalasu)",
    "State" : "Closed",
    "Created" : "8/4/2017 13:28",
    "Closed" : "8/4/2017 13:48",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BW(Business Warehouse)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Failure alert delay",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "Issue:ZHT_CMS_CI_HISTORY_DELTA is failed.RCA:Due to user lock issueResolution summary:Deleted the entried in sm12 and PC is completed.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0698009",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))Job \"ZHCM_ET_DLY_PA_BN_ETL_Table_Load_NUS\"  (47194976) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Pavitra Kanneganti (pkannega)",
    "State" : "Closed",
    "Created" : "8/4/2017 18:23",
    "Closed" : "8/8/2017 9:04",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Connection Issue",
    "Closed_by" : "Pavitra Kanneganti (pkannega)",
    "Close_notes" : "The job is running successfully with completed status, there is a issue with ETL connection. now ETL is up. no issues found so far",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0698010",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))Job \"ZHCM_WW_CYC_Load_WWHRDB_Hourly_Data_To_HRETL_Database_NUS\"  (47224210) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Pavitra Kanneganti (pkannega)",
    "State" : "Closed",
    "Created" : "8/4/2017 18:27",
    "Closed" : "8/8/2017 9:01",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "No issue found",
    "CI_Specific_Code" : "Duplicate",
    "Closed_by" : "Pavitra Kanneganti (pkannega)",
    "Close_notes" : "The job is running sucessfully with completed status",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0698126",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP FI (Finance))Job \"ZFICO_AR_DLY_PRars117D\"  (47207647) ended with status Error",
    "Assignment_group" : "SAP FICO Support",
    "Assigned_to" : "Abhishek kumar Singh (aksingh)",
    "State" : "Closed",
    "Created" : "8/5/2017 6:34",
    "Closed" : "8/7/2017 12:18",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP FI (Finance)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job Stuck/Error",
    "Closed_by" : "Abhishek kumar Singh (aksingh)",
    "Close_notes" : "Issue: Redwood Job failureRCA: Connection issueResolution: monitored the job and it is running fine now.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0698360",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))ZHCM_OM_DLY_Update_PD_Profile_In_PRD_Automating_Chief_Roles_NUS (47283400) ended with status Killed",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/7/2017 12:48",
    "Closed" : "8/7/2017 13:49",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Duplicate",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "(CI=SAP HCM (Human Capital Management))ZHCM_OM_DLY_Update_PD_Profile_In_PRD_Automating_Chief_Roles_NUS (47283400) ended with status KilledRCA:N/Asolution:Closing this as a duplicate.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0698361",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Roles_NUS (47283386) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/7/2017 12:48",
    "Closed" : "8/7/2017 13:39",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Duplicate",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "Issue:(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Roles_NUS (47283386) ended with status ErrorRCA:N/Asolution:closing this as a duplicate as we are working on the same with the other incident.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0698362",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Chief_Roles_NUS (47283379) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Swathi Naru (snaru)",
    "State" : "Closed",
    "Created" : "8/7/2017 12:48",
    "Closed" : "8/7/2017 13:42",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Duplicate",
    "Closed_by" : "Swathi Naru (snaru)",
    "Close_notes" : "issue:(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Chief_Roles_NUS (47283379) ended with status ErrorRCA:N/Asolution:Closing this as a duplicate.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0698406",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BW(Business Warehouse))Redwood PRD: Job Ended Not OK.",
    "Assignment_group" : "SAP BW Support",
    "Assigned_to" : "Nagaswami Gongidi (ngongidi)",
    "State" : "Closed",
    "Created" : "8/7/2017 15:11",
    "Closed" : "8/7/2017 17:27",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BW(Business Warehouse)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Failure alert delay",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "ISsue: ZIM_INV_DM_TD_D_D is failed.RCA:Due to object locked by userResolution Sumamry:Deleted the red request and manually run the step",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0698606",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_TMPY_MYS_Inbound_Jobs_Ver2_NUS (47297340) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Hare Dora (hdora)",
    "State" : "Closed",
    "Created" : "8/7/2017 23:05",
    "Closed" : "8/8/2017 12:09",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Connection Issue",
    "Closed_by" : "Hare Dora (hdora)",
    "Close_notes" : "Issue:JC_ZHCM_TMPY_MYS_Inbound_Jobs_Ver2_NUS (47297340) ended with status ErrorRCA: The job failed due to PI connection issue and reexecutedSummary:  Job run manually step by step and completed successfully.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0698915",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP SD (Sales and Distribution))  PRD: (Job \"ZSDLE_CYC_MOV_ShipInfoErrModus\"- FTP Ship Info Error to ModusLink) being set to status Error.",
    "Assignment_group" : "SAP SD Support",
    "Assigned_to" : "Prasanth Vallepu (pvallepu)",
    "State" : "Closed",
    "Created" : "8/9/2017 2:15",
    "Closed" : "8/11/2017 2:25",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP SD (Sales and Distribution)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Connection Issue",
    "Closed_by" : "Prasanth Vallepu (pvallepu)",
    "Close_notes" : "Issue : \"ZSDLE_CYC_MOV_ShipInfoErrModus\"- FTP Ship Info Error to ModusLink being set to status Error.RCA: Connection issue Resolution summary : Job is running fine now",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0699164",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP SD (Sales and Distribution))  PRD: (Job \"ZSDLE_CYC_REC_ShipInfoDHL1\"- Receive Ship Info From DHL1) being set to status Error.",
    "Assignment_group" : "SAP SD Support",
    "Assigned_to" : "Prasanth Vallepu (pvallepu)",
    "State" : "Closed",
    "Created" : "8/10/2017 1:01",
    "Closed" : "8/11/2017 2:24",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP SD (Sales and Distribution)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Connection Issue",
    "Closed_by" : "Prasanth Vallepu (pvallepu)",
    "Close_notes" : "Issue : Job \"ZSDLE_CYC_REC_ShipInfoDHL1\"- Receive Ship Info From DHL1 being set to status Error.RCA: Connection issue Resolution summary : Job is running fine now",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0699215",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP FI (Finance))Job \"ZFICO_AR_DLY_PRars117D\"  (47374042) ended with status Error",
    "Assignment_group" : "Redwood Support",
    "Assigned_to" : "santhosh kumar Siddamsetty (siddams)",
    "State" : "Closed",
    "Created" : "8/10/2017 6:32",
    "Closed" : "8/16/2017 22:31",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP FI (Finance)",
    "Cause_Code" : "Software",
    "CI_Specific_Code" : "Job Stuck/Error",
    "Closed_by" : "santhosh kumar Siddamsetty (siddams)",
    "Close_notes" : "Issue: job failedResolution:  There was an intermittent issue, which caused the  job to end with Error. Now the jobs are running fine.RCA:NA",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0699288",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Roles_NUS (47382966) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Mayuri Tambekar (mtambeka)",
    "State" : "Closed",
    "Created" : "8/10/2017 12:48",
    "Closed" : "8/11/2017 0:38",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Cancelled",
    "Closed_by" : "Mayuri Tambekar (mtambeka)",
    "Close_notes" : "Issue - JC_ZHCM_OM_DLY_Automating_Roles_NUS ended with errorRCA - No issues foundSolution - Redwood job is working fine, cancelling the incident.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0699289",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))ZHCM_OM_DLY_Update_PD_Profile_In_PRD_Automating_Chief_Roles_NUS (47382980) ended with status Killed",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Mayuri Tambekar (mtambeka)",
    "State" : "Closed",
    "Created" : "8/10/2017 12:48",
    "Closed" : "8/11/2017 0:34",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Cancelled",
    "Closed_by" : "Mayuri Tambekar (mtambeka)",
    "Close_notes" : "Issue - ZHCM_OM_DLY_Update_PD_Profile_In_PRD_Automating_Chief_Roles_NUS ended with errorRCA - No issues found Solution - Redwood job is working fine.Cancelling the incident.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0699290",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_OM_DLY_Automating_Chief_Roles_NUS (47382959) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Mayuri Tambekar (mtambeka)",
    "State" : "Closed",
    "Created" : "8/10/2017 12:48",
    "Closed" : "8/11/2017 0:36",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Cancelled",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Cancelled",
    "Closed_by" : "Mayuri Tambekar (mtambeka)",
    "Close_notes" : "Issue - JC_ZHCM_OM_DLY_Automating_Chief_Roles_NUS ended with errorRCA - No issues found Solution - Redwood job is working fine.Cancelling the incident.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0699568",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BW(Business Warehouse))Redwood PRD: Job Ended Not OK.",
    "Assignment_group" : "SAP BW Support",
    "Assigned_to" : "Nagaswami Gongidi (ngongidi)",
    "State" : "Closed",
    "Created" : "8/11/2017 12:58",
    "Closed" : "8/11/2017 13:29",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BW(Business Warehouse)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Failure alert delay",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "Issue:ZFIGL_ZFIGLO02_D_D is failed.RCA:Same loading step in cOPA chain.Resolution Summary:Once cOPA completion.we repeaed the step.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0699593",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BW(Business Warehouse))Redwood PRD: Job Ended Not OK.",
    "Assignment_group" : "SAP BW Support",
    "Assigned_to" : "Suganya Balasubramani (sbalasu)",
    "State" : "Closed",
    "Created" : "8/11/2017 14:18",
    "Closed" : "8/11/2017 14:33",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BW(Business Warehouse)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Failure alert delay",
    "Closed_by" : "Suganya Balasubramani (sbalasu)",
    "Close_notes" : "Issue: ZKPI_OHD_TD_CCAFCST_D_D si failed.RCA:CCR job is also running same timeResolution Summary:Repeated the step after cCR job completion.Chain is compelted.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0699939",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP FI (Finance))ZFICO_Vistex_DLY_IPDOC_ACCRUAL_SAP (47469183) ended with status Error",
    "Assignment_group" : "Redwood Support",
    "Assigned_to" : "Vinay kumar Balivada (vbalivad)",
    "State" : "Closed",
    "Created" : "8/13/2017 0:42",
    "Closed" : "8/16/2017 17:15",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP Redwood",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Connection Issue",
    "Closed_by" : "Vinay kumar Balivada (vbalivad)",
    "Close_notes" : "Issue:(CI=SAP ERP FI (Finance))ZFICO_Vistex_DLY_IPDOC_ACCRUAL_SAP (47469183) ended with status ErrorRCA: The status was ended in not OK due to an intermittent issue. Resolution:- The job is running fine now.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0700006",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BASIS)Redwood PRD: JC_ZFICO_A_AP_CYC_ATLUT: Job Exceeded Run Time Limit of 30 mins.",
    "Assignment_group" : "Redwood Support",
    "Assigned_to" : "Rangarao Guggilam (rguggila)",
    "State" : "Closed",
    "Created" : "8/13/2017 7:01",
    "Closed" : "8/17/2017 12:09",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP Redwood",
    "Cause_Code" : "Workflow",
    "CI_Specific_Code" : "Application Issue",
    "Closed_by" : "Rangarao Guggilam (rguggila)",
    "Close_notes" : "Issue : (CI=SAP BASIS)Redwood PRD: JC_ZFICO_A_AP_CYC_ATLUT: Job Exceeded Run Time Limit of 30 mins.Resolution : Due to long running batch job this job is cancelled.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700199",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BPC NW EPM (Sales Forecasting))ATL Redwood PRD: Process SF Product Master Data Hierarchy Load Ended Not Ok.",
    "Assignment_group" : "SAP BPC Support",
    "Assigned_to" : "Suvarna Vandana (suvarna)",
    "State" : "Closed",
    "Created" : "8/14/2017 11:54",
    "Closed" : "8/16/2017 9:29",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BPC NW EPM (Sales Forecasting)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Application Issue",
    "Closed_by" : "Suvarna Vandana (suvarna)",
    "Close_notes" : "Issue : Master data job failure in productionRCA : System connectivity issue between BWP and BPPResolution Summary : SAP Basis team has updated the connections.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700265",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BW(Business Warehouse))Redwood PRD: Job Ended Not OK.",
    "Assignment_group" : "SAP BW Support",
    "Assigned_to" : "Ramakrishna reddy Kothakapu (rkothaka)",
    "State" : "Closed",
    "Created" : "8/14/2017 16:08",
    "Closed" : "8/14/2017 16:41",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BW(Business Warehouse)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Definition",
    "Closed_by" : "Ramakrishna reddy Kothakapu (rkothaka)",
    "Close_notes" : "Issue :( CI=SAP BW (Business Warehouse)) BW Production: BW Job Ended Not OK.Root cause: Job failure is due to background job failure.Resolution: Repeated the job & it ran to success.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
},
{
    "IncidentNumber" : "INC0700281",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP SD (Sales and Distribution))  PRD: (Job Chain \"JC_ZSDOM_UPD_CommitFile_ATP\" - Commit SalesOrder from ATP) being set to status Error.",
    "Assignment_group" : "SAP SD Support",
    "Assigned_to" : "Prasanth Vallepu (pvallepu)",
    "State" : "Closed",
    "Created" : "8/14/2017 17:10",
    "Closed" : "8/17/2017 17:39",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP SD (Sales and Distribution)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Connection Issue",
    "Closed_by" : "Prasanth Vallepu (pvallepu)",
    "Close_notes" : "Issue : Job Chain \"JC_ZSDOM_UPD_CommitFile_ATP\" - Commit SalesOrder from ATP being set to status Error.RCA: Connection issueResolution summary : Job is running fine now",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700282",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP SD (Sales and Distribution))  PRD: (Job \"JC_ZSDLE_CYC_EXT_Shipment_DHL\" -  DHL Shipment Visibility Extract) being set to status Error.",
    "Assignment_group" : "SAP SD Support",
    "Assigned_to" : "Prasanth Vallepu (pvallepu)",
    "State" : "Closed",
    "Created" : "8/14/2017 17:12",
    "Closed" : "8/17/2017 17:43",
    "Task_type" : "Incident",
    "Subcategory" : "Business Service",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP ERP SD (Sales and Distribution)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Connection Issue",
    "Closed_by" : "Prasanth Vallepu (pvallepu)",
    "Close_notes" : "Issue : Job \"JC_ZSDLE_CYC_EXT_Shipment_DHL\" -  DHL Shipment Visibility Extract) being set to status Error.RCA: Connection issueResolution summary : Job is running fine now",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700284",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP FI (Finance))JC_ZFICO_A2_Vistex_GTS_PostBill_ATLUT (47477749) ended with status Error",
    "Assignment_group" : "Redwood Support",
    "Assigned_to" : "santhosh kumar Siddamsetty (siddams)",
    "State" : "Closed",
    "Created" : "8/14/2017 17:14",
    "Closed" : "8/16/2017 22:35",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP Redwood",
    "Cause_Code" : "Workflow",
    "CI_Specific_Code" : "Application Issue",
    "Closed_by" : "santhosh kumar Siddamsetty (siddams)",
    "Close_notes" : "Issue: Job failedResolution: There was a intermittent issue, which causes the job ended with error. Jobs are running fine.However we are monitoring subsequest runs.RCA:NA",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700285",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP FI (Finance))JC_ZFICO_C_AR_DLY_ATLUT (47491520) ended with status Error",
    "Assignment_group" : "Redwood Support",
    "Assigned_to" : "Rangarao Guggilam (rguggila)",
    "State" : "Closed",
    "Created" : "8/14/2017 17:18",
    "Closed" : "8/16/2017 14:34",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP Redwood",
    "Cause_Code" : "Workflow",
    "CI_Specific_Code" : "Application Issue",
    "Closed_by" : "Rangarao Guggilam (rguggila)",
    "Close_notes" : "Issue:(CI=SAP ERP FI (Finance))JC_ZFICO_C_AR_DLY_ATLUT (47491520) ended with status ErrorResolution: Due to long running Batch job only, this Job chain cancelled.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700295",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BASIS)Redwood PRD: JC_ZFICO_A_AP_CYC_ATLUT: Job Exceeded Run Time Limit of 30 mins.",
    "Assignment_group" : "Redwood Support",
    "Assigned_to" : "Rangarao Guggilam (rguggila)",
    "State" : "Closed",
    "Created" : "8/14/2017 18:01",
    "Closed" : "8/17/2017 12:11",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP Redwood",
    "Cause_Code" : "Software",
    "CI_Specific_Code" : "Application Issue",
    "Closed_by" : "Rangarao Guggilam (rguggila)",
    "Close_notes" : "Issue : (CI=SAP BASIS)Redwood PRD: JC_ZFICO_A_AP_CYC_ATLUT: Job Exceeded Run Time Limit of 30 mins.Resolution : Due to long running batch job this job is cancelled.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700313",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BASIS)Redwood PRD: JC_ZFICO_A_AP_CYC_ATLUT: Job Exceeded Run Time Limit of 30 mins.",
    "Assignment_group" : "Redwood Support",
    "Assigned_to" : "santhosh kumar Siddamsetty (siddams)",
    "State" : "Closed",
    "Created" : "8/14/2017 20:02",
    "Closed" : "8/16/2017 22:39",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP Redwood",
    "Cause_Code" : "Workflow",
    "CI_Specific_Code" : "Application Issue",
    "Closed_by" : "santhosh kumar Siddamsetty (siddams)",
    "Close_notes" : "Issue: jobs Resolution: There was an intermittent issue, which causes  job exceeds limit, Jobs are running fine now.RCA:NA",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700390",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP ERP FI (Finance))JC_ZFICO_A_AP_CYC_ATLUT_1 (47542371) ended with status Error",
    "Assignment_group" : "SAP Basis Support",
    "Assigned_to" : "santhosh kumar Siddamsetty (siddams)",
    "State" : "Closed",
    "Created" : "8/15/2017 0:25",
    "Closed" : "8/16/2017 22:46",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP Redwood",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Application Issue",
    "Closed_by" : "santhosh kumar Siddamsetty (siddams)",
    "Close_notes" : "Issue: Job errorResolution: There was an intermittent issue, which caused the  job to end with error. Now the jobs are running fine.RCA: NA",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700523",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP BW(Business Warehouse))Redwood PRD: Job Ended Not OK.",
    "Assignment_group" : "SAP BW Support",
    "Assigned_to" : "Ramakrishna reddy Kothakapu (rkothaka)",
    "State" : "Closed",
    "Created" : "8/15/2017 12:41",
    "Closed" : "8/15/2017 13:59",
    "Task_type" : "Incident",
    "Subcategory" : "ERP Misc",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP BW(Business Warehouse)",
    "Cause_Code" : "Job Failure",
    "CI_Specific_Code" : "Job: Failure alert delay",
    "Closed_by" : "Ramakrishna reddy Kothakapu (rkothaka)",
    "Close_notes" : "Issue :( CI=SAP BW (Business Warehouse)) BW Production: BW Job Ended Not OK.Root cause: Job failure is due to background job failure.Resolution: Repeated the job & it ran to success.",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
,
{
    "IncidentNumber" : "INC0700599",
    "Priority" : "4 - Low (Resolution SLA ? 5 Business days)",
    "Description" : "(CI=SAP HCM (Human Capital Management))JC_ZHCM_TMPY_SGP_Inbound_Jobs_IT2010_IT0015_NUS (46595137) ended with status Error",
    "Assignment_group" : "SAP HR/PY Support",
    "Assigned_to" : "Pavitra Kanneganti (pkannega)",
    "State" : "Closed",
    "Created" : "8/15/2017 19:35",
    "Closed" : "8/17/2017 8:23",
    "Task_type" : "Incident",
    "Subcategory" : "HR ERP",
    "Close_code" : "Solved (Permanently)",
    "Closure_CI" : "SAP HCM (Human Capital Management)",
    "Cause_Code" : "Master Data",
    "CI_Specific_Code" : "Incorrect/Missing Data",
    "Closed_by" : "Pavitra Kanneganti (pkannega)",
    "Close_notes" : "We have re-ran the required redwood job, the job is successfully ran with completed status",
    "Type" : "2",
    "TrainingFlag" : 0,
    "CustomerID" : 1
}
])
except Exception as e:
    print (e)

# %%
from bson import json_util

# %%
json_util.dumps(1)
# Out:
# str
